# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
#      -------------------------------------- 11.6/11.6 MB 115.1 kB/s eta 0:00:00
# ...
#      ------------------------------------- 508.0/508.0 kB 74.6 kB/s eta 0:00:00
# ...
#      -------------------------------------- 12.9/12.9 MB 127.8 kB/s eta 0:00:00
# ...
#      ------------------------------------- 346.6/346.6 kB 97.4 kB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 7.8/7.8 MB 85.3 kB/s eta 0:00:00
# ...
#      ------------------------------------ 216.0/216.0 kB 149.7 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.2/2.2 MB 86.9 kB/s eta 0:00:00
# ...
#      ------------------------------------ 104.1/104.1 kB 117.8 kB/s eta 0:00:00
# ...
#      -------------------------------------- 55.9/55.9 kB 224.8 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.6/2.6 MB 77.5 kB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 24.2
# ...

# %%
# !python --version
# Out:
# Python 3.10.10

# %%
# !pip freeze > requirements.txt

# %%
# !pip install seaborn
# Out:
# ...
#      ------------------------------------ 294.9/294.9 kB 264.1 kB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from data_loader import Load_data

# %%
df = Load_data('MIES_Dev_Data.csv')

# %%
print(df)
# Out:
#      Q1A\tQ1I\tQ1E\tQ2A\tQ2I\tQ2E\tQ3A\tQ3I\tQ3E\tQ4A\tQ4I\tQ4E\tQ5A\tQ5I\tQ5E\tQ6A\tQ6I\tQ6E\tQ7A\tQ7I\tQ7E\tQ8A\tQ8I\tQ8E\tQ9A\tQ9I\tQ9E\tQ10A\tQ10I\tQ10E\tQ11A\tQ11I\tQ11E\tQ12A\tQ12I\tQ12E\tQ13A\tQ13I\tQ13E\tQ14A\tQ14I\tQ14E\tQ15A\tQ15I\tQ15E\tQ16A\tQ16I\tQ16E\tQ17A\tQ17I\tQ17E\tQ18A\tQ18I\tQ18E\tQ19A\tQ19I\tQ19E\tQ20A\tQ20I\tQ20E\tQ21A\tQ21I\tQ21E\tQ22A\tQ22I\tQ22E\tQ23A\tQ23I\tQ23E\tQ24A\tQ24I\tQ24E\tQ25A\tQ25I\tQ25E\tQ26A\tQ26I\tQ26E\tQ27A\tQ27I\tQ27E\tQ28A\tQ28I\tQ28E\tQ29A\tQ29I\tQ29E\tQ30A\tQ30I\tQ30E\tQ31A\tQ31I\tQ31E\tQ32A\tQ32I\tQ32E\tQ33A\tQ33I\tQ33E\tQ34A\tQ34I\tQ34E\tQ35A\tQ35I\tQ35E\tQ36A\tQ36I\tQ36E\tQ37A\tQ37I\tQ37E\tQ38A\tQ38I\tQ38E\tQ39A\tQ39I\tQ39E\tQ40A\tQ40I\tQ40E\tQ41A\tQ41I\tQ41E\tQ42A\tQ42I\tQ42E\tQ43A\tQ43I\tQ43E\tQ44A\tQ44I\tQ44E\tQ45A\tQ45I\tQ45E\tQ46A\tQ46I\tQ46E\tQ47A\tQ47I\tQ47E\tQ48A\tQ48I\tQ48E\tQ49A\tQ49I\tQ49E\tQ50A\tQ50I\tQ50E\tQ51A\tQ51I\tQ51E\tQ52A\tQ52I\tQ52E\tQ53A\tQ53I\tQ53E\tQ54A\tQ54I\tQ54E\tQ55A\tQ55I\tQ55E\tQ56A\tQ56I\tQ56E\tQ57A\tQ57I\t
# ...

# %%
from data_processing import Data_processing

# %%
df = Data_processing.DevideToColumns('MIES_Dev_Data.csv')

# %%
df
# Out:
#       Q1A  Q1I   Q1E  Q2A  Q2I   Q2E  Q3A  Q3I    Q3E  Q4A  ...   Q91E  \
# 0       5   51  7107    3   91  2522    1   56   6180    2  ...   4609
# 1       5   39  6354    5   13  3092    1   12   5243    5  ...  10409
# 2       3   17  5397    4   35  2747    5   40   5262    3  ...   2691
# 3       5   41  3055    2   14  3348    1   13   5141    1  ...   3697
# 4       1   76  2542    2   54  1878    1   15   5637    1  ...   1662
# ...   ...  ...   ...  ...  ...   ...  ...  ...    ...  ...  ...    ...
# 7183    1   46  1328    4   82  3214    4   43   3360    5  ...   3495
# 7184    2    5  8786    5   24  2233    5   10  10387    5  ...   6088
# 7185    3   29  6618    5   44  2393    4   58   5768    5  ...   3425
# 7186    4   15  8321    2   18  6179    5   60   5037    1  ...  17416
# 7187    5   57  2950    2   66  2232    4   24   7095    4  ...   1901
#
#       country             dateload  introelapse  testelapse  surveyelapse  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7188 entries, 0 to 7187
# Columns: 282 entries, Q1A to IE
# dtypes: int64(280), object(2)
# memory usage: 15.5+ MB

# %%
Data_processing.EmptyData(df)
# Out:
# в столбце Q1A - 0 пустых значений
# в столбце Q1I - 0 пустых значений
# в столбце Q1E - 0 пустых значений
# в столбце Q2A - 0 пустых значений
# в столбце Q2I - 0 пустых значений
# в столбце Q2E - 0 пустых значений
# в столбце Q3A - 0 пустых значений
# в столбце Q3I - 0 пустых значений
# в столбце Q3E - 0 пустых значений
# в столбце Q4A - 0 пустых значений
# в столбце Q4I - 0 пустых значений
# в столбце Q4E - 0 пустых значений
# в столбце Q5A - 0 пустых значений
# в столбце Q5I - 0 пустых значений
# в столбце Q5E - 0 пустых значений
# в столбце Q6A - 0 пустых значений
# в столбце Q6I - 0 пустых значений
# в столбце Q6E - 0 пустых значений
# в столбце Q7A - 0 пустых значений
# в столбце Q7I - 0 пустых значений
# в столбце Q7E - 0 пустых значений
# в столбце Q8A - 0 пустых значений
# в столбце Q8I - 0 пустых значений
# в столбце Q8E - 0 пустых значений
# в столбце Q9A - 0 пустых значений
# в столбце Q9I - 0 пустых значений
# в столбце Q9E - 0 пустых значений
# ...

# %%
Data_processing.RemoveRowsWithMissingValues(df)

# %%
Data_processing.EmptyData(df)
# Out:
# в столбце Q1A - 0 пустых значений
# в столбце Q1I - 0 пустых значений
# в столбце Q1E - 0 пустых значений
# в столбце Q2A - 0 пустых значений
# в столбце Q2I - 0 пустых значений
# в столбце Q2E - 0 пустых значений
# в столбце Q3A - 0 пустых значений
# в столбце Q3I - 0 пустых значений
# в столбце Q3E - 0 пустых значений
# в столбце Q4A - 0 пустых значений
# в столбце Q4I - 0 пустых значений
# в столбце Q4E - 0 пустых значений
# в столбце Q5A - 0 пустых значений
# в столбце Q5I - 0 пустых значений
# в столбце Q5E - 0 пустых значений
# в столбце Q6A - 0 пустых значений
# в столбце Q6I - 0 пустых значений
# в столбце Q6E - 0 пустых значений
# в столбце Q7A - 0 пустых значений
# в столбце Q7I - 0 пустых значений
# в столбце Q7E - 0 пустых значений
# в столбце Q8A - 0 пустых значений
# в столбце Q8I - 0 пустых значений
# в столбце Q8E - 0 пустых значений
# в столбце Q9A - 0 пустых значений
# в столбце Q9I - 0 пустых значений
# в столбце Q9E - 0 пустых значений
# ...

# %%
from visualisation import Visualizer

# %%
viz = Visualizer(df)
viz.Barplot(df[df['country'] == 'BR'], 'testelapse', 'age')
# Время, проведенное в секундах на тестовых вопросах, в засисимости от возраста пользователей страны BR

# %%
viz = Visualizer(df)
viz.PieChart(df, 'engnat')
#engnat: «Английский — ваш родной язык?» 1=Да 2=Нет

# %%
# Фильтрация строк, где значение в столбце 'engnat' равно 0
filtered_df = df.loc[df['engnat'] == 0]
row_count = len(filtered_df)
print(f"Количество строк: {row_count}")
#print(filtered_df)
# Out:
# Количество строк: 16

# %%
viz = Visualizer(df)
viz.DonutChart(df, 'gender')
